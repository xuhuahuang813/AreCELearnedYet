# %%
import pickle
from lecarb.constants import PKL_PROTO
workloadSize = 1000
encode_path_list = [
    "data/census13/lstm/original_lstm-1k0323_200_123_colsAllDomain.pkl",
    "data/census13/lstm/original+original_ind_0.1_lstm-1k-IND0.1_200_123_colsAllDomain.pkl"
]
file_num = len(encode_path_list)

# %%
encode_pkl_list = []
for _ in encode_path_list:
    with open(_, 'rb') as file:
        data = pickle.load(file)
        encode_pkl_list.append(data)

# %%
for _ in range(len(encode_pkl_list)):
    print(len(encode_pkl_list[_]))
    print(encode_pkl_list[_].keys())
    print(sorted(encode_pkl_list[_].keys()))
# Out:
# 72
# ...

# %%
# for k_i in sorted(encode_pkl_list[_].keys()):
#     print(k_i)
#     for e_i in range(len(encode_pkl_list)):
#         print(encode_pkl_list[e_i][k_i])
#         # break
# Out:
# age
#          age  index_alldomain
# 0   0.000000              0.0
# 1   0.013699            135.0
# 2   0.027397            270.0
# 3   0.041096            405.0
# 4   0.054795            541.0
# ..       ...              ...
# 69  0.945205           9324.0
# 70  0.958904           9459.0
# 71  0.972603           9595.0
# 72  0.986301           9730.0
# 73  1.000000           9865.0
#
# [74 rows x 2 columns]
#          age  index_alldomain
# 0   0.000000              0.0
# 1   0.013699            135.0
# 2   0.027397            270.0
# 3   0.041096            405.0
# 4   0.054795            541.0
# ..       ...              ...
# 69  0.945205           9324.0
# 70  0.958904           9459.0
# 71  0.972603           9595.0
# 72  0.986301           9730.0
# 73  1.000000           9865.0
#
# [74 rows x 2 columns]
# age/education_num
#       age  education_num  index_alldomain
# 0     0.0       0.000000              0.0
# 1     0.0       0.066667              8.0
# ...
