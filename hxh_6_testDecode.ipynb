# %%
import torch

# 假设你的输入是 inputs
inputs = torch.randn(32, 50, 11)

print(inputs[0][49])
# Out:
# tensor([-0.4843,  0.4683, -2.4844,  0.2310,  1.0072,  1.5171,  3.0097,  1.7614,
#         -0.3731, -0.7878,  0.2353])

# %%
# 使用索引操作获取所需的数据
result = inputs[:, -1, :]

# 打印结果
print(result)
# Out:
# tensor([[-0.4843,  0.4683, -2.4844,  0.2310,  1.0072,  1.5171,  3.0097,  1.7614,
#          -0.3731, -0.7878,  0.2353],
#         [-0.5071,  0.1579, -0.2802, -0.5358, -1.9690,  0.3803,  0.4345,  0.0264,
#          -1.6689, -0.1960, -0.1946],
#         [ 0.0285,  0.6126, -0.0077,  0.9731, -0.2332,  0.0548,  0.1729,  0.8449,
#          -0.2233,  1.1977,  1.1448],
#         [ 1.3819, -0.1708,  1.8074,  0.2385,  0.6320, -1.6611,  0.2617, -0.6919,
#          -0.3925,  0.9245, -2.0220],
#         [ 0.6252, -0.2372, -0.6805, -2.1529, -1.0838, -1.6703, -0.3657, -0.9679,
#          -1.6441, -0.6628,  1.7128],
#         [-0.4107,  0.3325, -0.2855,  0.5584, -1.7566,  1.9727,  0.2260,  1.6187,
#          -1.2248, -0.3188, -0.2413],
#         [-1.2640, -2.0673, -1.1207,  1.2254, -1.0409, -0.3747, -1.4535,  0.0497,
#           1.7443, -0.9503, -0.9828],
#         [-1.4861,  0.3158,  1.8355, -1.2557,  0.6954, -0.0192, -0.9921,  0.5278,
#           0.3553,  0.5878,  0.1151],
# ...

# %%
result.shape
# Out:
# torch.Size([32, 11])
